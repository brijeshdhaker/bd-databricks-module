# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Add this line at the very top of your notebook to define the widget
dbutils.widgets.text("catalog", "workspace")
dbutils.widgets.text("schema", "default")

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
print(catalog)

# %%
# %fs ls /Volumes/workspace/default/dbx_volume

# %%
display(dbutils.fs.ls('/Volumes/workspace/default/dbx_volume'))

# %%
dbutils.fs.cp("/Workspace/Users/brijeshdhaker@gmail.com/notebooks/dbutils_fs_notebook", "/Volumes/main/default/my-volume/new-data.csv")

# %%
dbutils.fs.head("/Workspace/Users/brijeshdhaker@gmail.com/data/peoples/peoples.csv", 256)

# %%
dbutils.fs.ls("/Workspace/Users/brijeshdhaker@gmail.com/data/flights")

# %%
dbutils.fs.mv("/Workspace/Users/brijeshdhaker@gmail.com/data/peoples.csv", "/Workspace/Users/brijeshdhaker@gmail.com/data/peoples/peoples.csv")

# %%
dbutils.fs.put("/Workspace/Users/brijeshdhaker@gmail.com/data/hello.txt", "Hello, Databricks!", True)

# %%
dbutils.fs.rm("/Workspace/Users/brijeshdhaker@gmail.com/data/", True)

# %%
aws_bucket_name = "my-bucket"
mount_name = "s3-my-bucket"

dbutils.fs.mount("s3a://%s" % aws_bucket_name, "/mnt/%s" % mount_name)

# %%
dbutils.fs.unmount("/mnt/<mount-name>")

# %%
dbutils.fs.help("cp")

# %%
employee_df = spark.read.option("header", True) \
    .option("delimiter", ',') \
    .option("emptyValue", 'N/A') \
    .option("nullValue", 0) \
    .option("treatEmptyValuesAsNulls", True) \
    .options(inferSchema=True, delimiter=',') \
    .csv("/Volumes/workspace/default/dbx_volume/employee.csv")

display(employee_df)

# %%
import os

dbutils.fs.mkdirs('/Volumes/workspace/default/dbx_volume/sandbox')

# %%
import sys

sys.path.append("../src")
from bd_databricks_project import taxis

taxis.find_all_taxis().show(10)
